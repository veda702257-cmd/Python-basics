# %% [markdown]
# <a href="https://colab.research.google.com/github/veda702257-cmd/Python-basics/blob/main/Python_besics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 print("hello 🌎")
# Out:
# hello 🌎

# %%
print("veda")
# Out:
# veda

# %%
name="veda"
year="2026"
print("hello",name)
print (year)
# Out:
# hello veda
# 2026

# %%
name="veda"
year="2006"
print(name+year)
# Out:
# veda2006

# %%
a=4
b=6
print("add",a+b)
print("sub",a-b)
print("mul",a*b)
print("div",a/b)
# Out:
# add 10
# sub -2
# mul 24
# div 0.6666666666666666

# %%
def greet():
    print("hello world")
greet()
# Out:
# hello world

# %%
age=int(input("enter your age"))
if age>=18:
   print("you can vote")
else:
   print("come again next year")
# Out:
# enter your age19
# you can vote

# %%
def greet(name):
    print("hello",name)
greet("csd")
greet("cse")
greet("civil")
greet("mechanical")
# Out:
# hello csd
# hello cse
# hello civil
# hello mechanical
